# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer
from datasets import Dataset

# %% [markdown]
# ### Loading the Data

# %%
data_path = "../data/jutsus.json"
df = pd.read_json(data_path)
df.head()
# Out:
#                                           jutsu_name  \
# 0                      Antlion Ninja Arts: Ephemeral
# 1  Ankorodō Hiden Ninjutsu: Mochi Release: Infini...
# 2                              Apricot Blossom Droop
# 3                                       Annihilation
# 4                                        Animal Path
#
#                                           jutsu_type  \
# 0                                 Ninjutsu, Kinjutsu
# 1                                    Ninjutsu, Hiden
# 2                                 Taijutsu, Ninjutsu
# 3  Kekkei Genkai, Ninjutsu, Space–Time Ninjutsu, ...
# 4                   Kekkei Genkai, Ninjutsu, Dōjutsu
#
#                                    jutsu_description
# 0  This article is about the anime-only kinjutsu ...
# 1  The user causes the dumplings near them to gro...
# 2  Kurenai attacks her opponent with a combinatio...
# 3  Obito lands a series of punches and kicks to h...
# 4  This article is about the ability.  For other ...

# %% [markdown]
# Going to create a function to simplify the jutsus to Ninjutsu, Genjutsu and Taijutusu

# %%
def simplify_jutsus(jutsu):
    if "Genjutsu" in jutsu:
        return "Genjutsu"
    if "Ninjutsu" in jutsu:
        return "Ninjutsu"
    if "Taijutsu" in jutsu:
        return "Taijutsu"

# %%
df['jutsu_type_simplified'] = df['jutsu_type'].apply(simplify_jutsus)

# %%
df.head()
# Out:
#                                           jutsu_name  \
# 0                      Antlion Ninja Arts: Ephemeral
# 1  Ankorodō Hiden Ninjutsu: Mochi Release: Infini...
# 2                              Apricot Blossom Droop
# 3                                       Annihilation
# 4                                        Animal Path
#
#                                           jutsu_type  \
# 0                                 Ninjutsu, Kinjutsu
# 1                                    Ninjutsu, Hiden
# 2                                 Taijutsu, Ninjutsu
# 3  Kekkei Genkai, Ninjutsu, Space–Time Ninjutsu, ...
# 4                   Kekkei Genkai, Ninjutsu, Dōjutsu
#
#                                    jutsu_description jutsu_type_simplified
# 0  This article is about the anime-only kinjutsu ...              Ninjutsu
# 1  The user causes the dumplings near them to gro...              Ninjutsu
# 2  Kurenai attacks her opponent with a combinatio...              Ninjutsu
# 3  Obito lands a series of punches and kicks to h...              Ninjutsu
# 4  This article is about the ability.  For other ...              Ninjutsu

# %%
df['jutsu_type_simplified'].value_counts()
# Out:
# jutsu_type_simplified
# Ninjutsu    2271
# Taijutsu     398
# Genjutsu     101
# Name: count, dtype: int64

# %% [markdown]
# Here Ninjutsu has more samples than the other two, this could make a skewed decision based on the datset representation. We will deal with it by penalizing the function more for lesser datasets.

# %%
df['text'] = df['jutsu_name'] + ". " + df['jutsu_description']
df['jutsu'] = df['jutsu_type_simplified']
df = df[['text', 'jutsu']]
df = df.dropna()
df.head()
# Out:
#                                                 text     jutsu
# 0  Antlion Ninja Arts: Ephemeral. This article is...  Ninjutsu
# 1  Ankorodō Hiden Ninjutsu: Mochi Release: Infini...  Ninjutsu
# 2  Apricot Blossom Droop. Kurenai attacks her opp...  Ninjutsu
# 3  Annihilation. Obito lands a series of punches ...  Ninjutsu
# 4  Animal Path. This article is about the ability...  Ninjutsu

# %% [markdown]
# I am just creating a random funtion to clean our text and remove any noise in json file this could be used in any other project as well.

# %%
from bs4 import BeautifulSoup
class cleaner():
    def __init__(self):
        pass
    
    def put_line_breaks(self, text):
        return text.replace("<\p>", "<\p>\n")
    
    def remove_html_tag(self, text):
        clean_text = BeautifulSoup(text, "html.parser").get_text()
        return clean_text
    
    # def remove_special_characters(self, text): 
    #     return text.replace("\n", " ").replace("\r", "")
    
    def clean_text(self, text):
        text = self.put_line_breaks(text)
        text = self.remove_html_tag(text)
        # text = self.remove_special_characters(text)
        text = text.strip()
        return text
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/4b/_mj4qjj14rg6cxv5mbsj_j3c0000gn/T/ipykernel_66020/219021503.py:7: SyntaxWarning: invalid escape sequence '\p'
#   return text.replace("<\p>", "<\p>\n")
# /var/folders/4b/_mj4qjj14rg6cxv5mbsj_j3c0000gn/T/ipykernel_66020/219021503.py:7: SyntaxWarning: invalid escape sequence '\p'
#   return text.replace("<\p>", "<\p>\n")

# %%
text_column_name = 'text'
label_columdn_name = 'jutsu'

# %%
#Cleaning the text
cleaner = cleaner()
df['text_cleaned'] = df[text_column_name].apply(cleaner.clean_text)

# %%
df.head()
# Out:
#                                                 text     jutsu  \
# 0  Antlion Ninja Arts: Ephemeral. This article is...  Ninjutsu
# 1  Ankorodō Hiden Ninjutsu: Mochi Release: Infini...  Ninjutsu
# 2  Apricot Blossom Droop. Kurenai attacks her opp...  Ninjutsu
# 3  Annihilation. Obito lands a series of punches ...  Ninjutsu
# 4  Animal Path. This article is about the ability...  Ninjutsu
#
#                                         text_cleaned
# 0  Antlion Ninja Arts: Ephemeral. This article is...
# 1  Ankorodō Hiden Ninjutsu: Mochi Release: Infini...
# 2  Apricot Blossom Droop. Kurenai attacks her opp...
# 3  Annihilation. Obito lands a series of punches ...
# 4  Animal Path. This article is about the ability...

# %% [markdown]
# Tokenizing the input for the model to implemet.

# %%
#Encode Labels
le = preprocessing.LabelEncoder()
le.fit(df[label_columdn_name].tolist())
# Out:
# LabelEncoder()

# %%
label_dict = {index:label_name for index, label_name in enumerate(le.__dict__['classes_'].tolist())}
label_dict
# Out:
# {0: 'Genjutsu', 1: 'Ninjutsu', 2: 'Taijutsu'}

# %%
df['label'] = le.transform(df[label_columdn_name].tolist())
df.head()
# Out:
#                                                 text     jutsu  \
# 0  Antlion Ninja Arts: Ephemeral. This article is...  Ninjutsu
# 1  Ankorodō Hiden Ninjutsu: Mochi Release: Infini...  Ninjutsu
# 2  Apricot Blossom Droop. Kurenai attacks her opp...  Ninjutsu
# 3  Annihilation. Obito lands a series of punches ...  Ninjutsu
# 4  Animal Path. This article is about the ability...  Ninjutsu
#
#                                         text_cleaned  label
# 0  Antlion Ninja Arts: Ephemeral. This article is...      1
# 1  Ankorodō Hiden Ninjutsu: Mochi Release: Infini...      1
# 2  Apricot Blossom Droop. Kurenai attacks her opp...      1
# 3  Annihilation. Obito lands a series of punches ...      1
# 4  Animal Path. This article is about the ability...      1

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42, stratify=df[label_columdn_name])
print(df_train['jutsu'].value_counts())
print(df_test['jutsu'].value_counts())
# Out:
# jutsu
# Ninjutsu    1817
# Taijutsu     318
# Genjutsu      81
# Name: count, dtype: int64
# jutsu
# Ninjutsu    454
# Taijutsu     80
# Genjutsu     20
# Name: count, dtype: int64

# %%
model_name = "distilbert/distilbert-base-uncased"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
def preprocess_funtion(tokenizer, example):
    return tokenizer(example['text_cleaned'], truncation=True, padding='max_length', max_length=512, return_tensors="pt")

# %%
#Convert Pandas to Hugging face dataset
train_dataset = Dataset.from_pandas(df_train)
test_dataset = Dataset.from_pandas(df_test)

#Tokenize the datatset
tokenizer_train = train_dataset.map(lambda examples: preprocess_funtion(tokenizer, examples), batched=True)
tokenizer_test = test_dataset.map(lambda examples: preprocess_funtion(tokenizer, examples), batched=True)
# Out:
# Map: 100%|██████████| 2216/2216 [00:00<00:00, 5162.37 examples/s]
# Map: 100%|██████████| 554/554 [00:00<00:00, 5972.60 examples/s]
